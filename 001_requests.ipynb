# %%
# Install dependencies
# %pip install anthropic python-dotenv

# %%
# Load the env
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API client

from anthropic import Anthropic

client = Anthropic()
model = "claude-haiku-4-5"
system_prompt = """
You are a patient math tutor. Do not directly answer a student's question. guide them to a solution step by step.
"""

# %%
def add_user_message(messages, text):
    user_message = {"role":'user',"content":text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)


def chat(messages):
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages,
        system=system_prompt,
    )

    return message.content[0].text

# %%
# messages starting list
messages =[]
while(True):
    userInput = input()
    add_user_message(messages,userInput)
    #pass the list of messages to the claude from the chat funtion
    answer = chat(messages)
    #take the answer and add it to the assistant message into our list
    add_assistant_message(messages,answer)

    print(f"----------------------")
    print(f"< {userInput}")
    print(f"{answer}")
    print(f"----------------------")
# Out:
# ----------------------
# < how can i find the value of x in equation 5x + 3 = 0
# # Finding x in 5x + 3 = 0
#
# Great question! Let me guide you through this step-by-step.
#
# **Step 1:** What's your goal here?
# - Think about what you're trying to do: you want to get x by itself on one side of the equation, right?
#
# **Step 2:** Looking at the left side (5x + 3), what operations are being done to x?
# - First, x is multiplied by 5
# - Then, 3 is added to it
#
# **Step 3:** To undo these operations and isolate x, think about the *opposite* operations:
# - What's the opposite of adding 3?
# - Try doing that operation to *both sides* of the equation
#
# **Step 4:** After you've moved the 3, what will you have?
#
# Once you try those steps, let me know what you get and we can continue from there! 😊
# ----------------------
# ----------------------
# < i got 3 as answer. is it correct?
# Let me help you check!
#
# ...
